# %% [markdown]
# <h2 style="text-align: center; background-color: #4d648d; font-family:Arial; color: white; padding: 13px; line-height: 1; border-radius:10px">Traiter les valeurs catégorielles 🔢</h2>

# %%
import pandas as pd
df = pd.read_csv("db_customers.csv")
df.head()
# Out:
#                            order_id order_status order_purchase_timestamp  \
# 0  e481f51cbdc54678b7cc49136f2d6af7    delivered      2017-10-02 10:56:33
# 1  e481f51cbdc54678b7cc49136f2d6af7    delivered      2017-10-02 10:56:33
# 2  e481f51cbdc54678b7cc49136f2d6af7    delivered      2017-10-02 10:56:33
# 3  53cdb2fc8bc7dce0b6741e2150273451    delivered      2018-07-24 20:41:37
# 4  47770eb9100c2d0c44946d9cf07ec65d    delivered      2018-08-08 08:38:49
#
#   order_delivered_customer_date payment_type  payment_installments  \
# 0           2017-10-10 21:25:13  credit_card                   1.0
# 1           2017-10-10 21:25:13      voucher                   1.0
# 2           2017-10-10 21:25:13      voucher                   1.0
# 3           2018-08-07 15:27:45       boleto                   1.0
# 4           2018-08-17 18:06:29  credit_card                   3.0
#
#    payment_value  review_score                customer_unique_id  \
# ...

# %% [markdown]
# Les possibilités de traitements des valeurs catégorielles :
#     - One Hot Encoding / Get Dummies Encoding
#     - Label Encoding

# %%
encoded_status = pd.get_dummies(df, columns=['order_status'])
encoded_status.head(20)
# Out:
#                             order_id order_purchase_timestamp  \
# 0   e481f51cbdc54678b7cc49136f2d6af7      2017-10-02 10:56:33
# 1   e481f51cbdc54678b7cc49136f2d6af7      2017-10-02 10:56:33
# 2   e481f51cbdc54678b7cc49136f2d6af7      2017-10-02 10:56:33
# 3   53cdb2fc8bc7dce0b6741e2150273451      2018-07-24 20:41:37
# 4   47770eb9100c2d0c44946d9cf07ec65d      2018-08-08 08:38:49
# 5   949d5b44dbf5de918fe9c16f97b45f8a      2017-11-18 19:28:06
# 6   ad21c59c0840e6cb83a9ceb5573f8159      2018-02-13 21:18:39
# 7   a4591c265e18cb1dcee52889e2d8acc3      2017-07-09 21:57:05
# 8   136cce7faa42fdb2cefd53fdc79a6098      2017-04-11 12:22:08
# 9   6514b8ad8028c9f2cc2374ded245783f      2017-05-16 13:10:30
# 10  76c6e866289321a7c93b82b54852dc33      2017-01-23 18:29:09
# 11  e69bfb5eb88e0ed6a785585b27e16dbf      2017-07-29 11:55:02
# 12  e69bfb5eb88e0ed6a785585b27e16dbf      2017-07-29 11:55:02
# 13  e6ce16cb79ec1d90b1da9085a6118aeb      2017-05-16 19:41:10
# ...

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df['product_category_name_english'] = label_encoder.fit_transform(df['product_category_name_english'])
df.head()
# Out:
#                            order_id order_status order_purchase_timestamp  \
# 0  e481f51cbdc54678b7cc49136f2d6af7    delivered      2017-10-02 10:56:33
# 1  e481f51cbdc54678b7cc49136f2d6af7    delivered      2017-10-02 10:56:33
# 2  e481f51cbdc54678b7cc49136f2d6af7    delivered      2017-10-02 10:56:33
# 3  53cdb2fc8bc7dce0b6741e2150273451    delivered      2018-07-24 20:41:37
# 4  47770eb9100c2d0c44946d9cf07ec65d    delivered      2018-08-08 08:38:49
#
#   order_delivered_customer_date payment_type  payment_installments  \
# 0           2017-10-10 21:25:13  credit_card                   1.0
# 1           2017-10-10 21:25:13      voucher                   1.0
# 2           2017-10-10 21:25:13      voucher                   1.0
# 3           2018-08-07 15:27:45       boleto                   1.0
# 4           2018-08-17 18:06:29  credit_card                   3.0
#
#    payment_value  review_score                customer_unique_id  \
# ...
